# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import datasets

# %%
df = pd.read_csv('X_Train.csv')
df.head()
# Out:
#           id  patient_no       cast  gender age group weight  \
# 0  122283168   113223627  Caucasian  Female   [80-90)      ?
# 1   97835454    25776306  Caucasian  Female   [80-90)      ?
# 2  431347352    42491844  Caucasian    Male   [50-60)      ?
# 3  153301914    87104907  Caucasian  Female   [70-80)      ?
# 4  304851608    70844364  Caucasian  Female  [90-100)      ?
#
#    admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                 1                         1                    7
# 1                 5                         3                   17
# 2                 3                         1                    1
# 3                 5                         3                    1
# 4                 1                         3                    7
#
#    time_in_hospital  ... examide citoglipton  insulin  glyburide-metformin  \
# 0                 4  ...      No          No       No                   No
# ...

# %%
df["cast"].unique()
# Out:
# array(['Caucasian', 'AfricanAmerican', 'Other', '?', 'Asian', 'Hispanic'],
#       dtype=object)

# %%
df["cast"] = df["cast"].map({ "Caucasian" : 1, "AfricanAmerican" : 2, "Other": 3, "?": 3, "Asian": 4, "Hispanic": 5}.get)
df.head()
# Out:
#           id  patient_no  cast  gender age group weight  admission_typeid  \
# 0  122283168   113223627     1  Female   [80-90)      ?                 1
# 1   97835454    25776306     1  Female   [80-90)      ?                 5
# 2  431347352    42491844     1    Male   [50-60)      ?                 3
# 3  153301914    87104907     1  Female   [70-80)      ?                 5
# 4  304851608    70844364     1  Female  [90-100)      ?                 1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  ...  \
# 0                         1                    7                 4  ...
# 1                         3                   17                 3  ...
# 2                         1                    1                 1  ...
# 3                         3                    1                 3  ...
# 4                         3                    7                 5  ...
#
#   examide citoglipton  insulin  glyburide-metformin  glipizide-metformin  \
# ...

# %%
df.groupby('cast').count()
# Out:
#          id  patient_no  gender  age group  weight  admission_typeid  \
# cast
# 1     53284       53284   53284      53284   53284             53284
# 2     13433       13433   13433      13433   13433             13433
# 3      2658        2658    2658       2658    2658              2658
# 4       466         466     466        466     466               466
# 5      1395        1395    1395       1395    1395              1395
#
#       discharge_disposition_id  admission_source_id  time_in_hospital  \
# cast
# 1                        53284                53284             53284
# 2                        13433                13433             13433
# 3                         2658                 2658              2658
# 4                          466                  466               466
# 5                         1395                 1395              1395
#
#       payer_code  ...  examide  citoglipton  insulin  glyburide-metformin  \
# cast              ...
# ...

# %%
df["gender"].unique()
# Out:
# array(['Female', 'Male', 'Unknown/Invalid'], dtype=object)

# %%
df["gender"] = df["gender"].map({ "Female" : 0, "Male" : 1, "Unknown/Invalid":2}.get)
df.groupby('gender').count()
# Out:
#            id  patient_no   cast  age group  weight  admission_typeid  \
# gender
# 0       38212       38212  38212      38212   38212             38212
# 1       33022       33022  33022      33022   33022             33022
# 2           2           2      2          2       2                 2
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# gender
# 0                          38212                38212             38212
# 1                          33022                33022             33022
# 2                              2                    2                 2
#
#         payer_code  ...  examide  citoglipton  insulin  glyburide-metformin  \
# gender              ...
# 0            38212  ...    38212        38212    38212                38212
# 1            33022  ...    33022        33022    33022                33022
# 2                2  ...        2            2        2                    2
#
# ...

# %%
df
# Out:
#               id  patient_no  cast  gender age group weight  admission_typeid  \
# 0      122283168   113223627     1       0   [80-90)      ?                 1
# 1       97835454    25776306     1       0   [80-90)      ?                 5
# 2      431347352    42491844     1       1   [50-60)      ?                 3
# 3      153301914    87104907     1       0   [70-80)      ?                 5
# 4      304851608    70844364     1       0  [90-100)      ?                 1
# ...          ...         ...   ...     ...       ...    ...               ...
# 71231   64367586    89250084     1       0   [80-90)      ?                 2
# 71232  290180694    44177697     1       1   [60-70)      ?                 3
# 71233  130101072   113734728     1       0   [80-90)      ?                 2
# 71234   26933646   107965575     1       0   [80-90)      ?                 2
# 71235  189027114    71449254     1       0   [50-60)      ?                 1
#
# ...

# %%
df["age group"].unique()
# Out:
# array(['[80-90)', '[50-60)', '[70-80)', '[90-100)', '[60-70)', '[20-30)',
#        '[40-50)', '[30-40)', '[10-20)', '[0-10)'], dtype=object)

# %%
df["age group"] = df["age group"].map({"[80-90)": 1, "[50-60)": 2, "[70-80)": 3, "[90-100)": 4, "[60-70)": 5, "[20-30)": 6, "[40-50)": 7, "[30-40)": 8, "[10-20)": 9, "[0-10)": 10}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["examide"].unique()
# Out:
# array(['No'], dtype=object)

# %%
df["examide"] = df["examide"].map({"No":1}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["citoglipton"].unique()
# Out:
# array(['No'], dtype=object)

# %%
df["citoglipton"] = df["citoglipton"].map({"No":1}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["insulin"].unique()
# Out:
# array(['No', 'Steady', 'Up', 'Down'], dtype=object)

# %%
df["insulin"] = df["insulin"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["glyburide-metformin"].unique()
# Out:
# array(['No', 'Steady', 'Up', 'Down'], dtype=object)

# %%
 df["glyburide-metformin"] =  df["glyburide-metformin"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["glipizide-metformin"].unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df["glipizide-metformin"] = df["glipizide-metformin"].map({"No":1,"Steady":2}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["glimepiride-pioglitazone"].unique()
# Out:
# array(['No'], dtype=object)

# %%
 df["glimepiride-pioglitazone"] =  df["glimepiride-pioglitazone"].map({"No":1}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["metformin-rosiglitazone"].unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df["metformin-rosiglitazone"] = df["metformin-rosiglitazone"].map({"No": 1, "Steady":2}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
 df["metformin-pioglitazone"].unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df["metformin-pioglitazone"] = df["metformin-pioglitazone"].map({"No":1, "Steady":2}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["change"].unique()
# Out:
# array(['No', 'Ch'], dtype=object)

# %%
df["change"] = df["change"].map({"No":1, "Ch":2}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["Med"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Med"] = df["Med"].map({"Yes":1, "No":2}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["tolazamide"].unique()
# Out:
# array(['No', 'Steady', 'Up'], dtype=object)

# %%
df["tolazamide"] = df["tolazamide"].map({"No":1, "Steady":2,"Up":3}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["troglitazone"].unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df['troglitazone'] = df["troglitazone"].map({"No":1,"Steady":2}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["miglitol"].unique()
# Out:
# array(['No', 'Steady', 'Down', 'Up'], dtype=object)

# %%
df["miglitol"] = df["miglitol"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["acarbose"].unique()
# Out:
# array(['No', 'Steady', 'Down', 'Up'], dtype=object)

# %%
df["acarbose"] = df["acarbose"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["rosiglitazone"].unique()
# Out:
# array(['No', 'Steady', 'Down', 'Up'], dtype=object)

# %%
 df["rosiglitazone"] = df["rosiglitazone"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["pioglitazone"].unique()
# Out:
# array(['No', 'Steady', 'Up', 'Down'], dtype=object)

# %%
df["pioglitazone"] = df["pioglitazone"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["tolbutamide"].unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df["tolbutamide"] = df["tolbutamide"].map({"No":1,"Steady":2}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["glyburide"].unique()
# Out:
# array(['No', 'Steady', 'Up', 'Down'], dtype=object)

# %%
 df["glyburide"] =  df["glyburide"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["glipizide"].unique()
# Out:
# array(['No', 'Steady', 'Down', 'Up'], dtype=object)

# %%
df["glipizide"] = df["glipizide"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["acetohexamide"].unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df["acetohexamide"] = df["acetohexamide"].map({"No":1,"Steady":2}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["glimepiride"].unique()
# Out:
# array(['Steady', 'No', 'Up', 'Down'], dtype=object)

# %%
 df["glimepiride"] = df["glimepiride"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["chlorpropamide"].unique()
# Out:
# array(['No', 'Steady', 'Up'], dtype=object)

# %%
 df["chlorpropamide"] =  df["chlorpropamide"].map({"No":1,"Steady":2, "Up":3}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["nateglinide"].unique()
# Out:
# array(['No', 'Steady', 'Up', 'Down'], dtype=object)

# %%
 df["nateglinide"] = df["nateglinide"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["repaglinide"].unique()
# Out:
# array(['No', 'Steady', 'Down', 'Up'], dtype=object)

# %%
df["repaglinide"] = df["repaglinide"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["metformin"].unique()
# Out:
# array(['No', 'Up', 'Steady', 'Down'], dtype=object)

# %%
df["metformin"] = df["metformin"].map({"No":1,"Steady":2, "Up":3, "Down":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["A1Cresult"].unique()
# Out:
# array(['Norm', 'None', '>8', '>7'], dtype=object)

# %%
 df["A1Cresult"] = df["A1Cresult"].map({"Norm":1,"None":2, ">8":3, ">7":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["max_glu_serum"].unique()
# Out:
# array(['None', '>300', 'Norm', '>200'], dtype=object)

# %%
df["max_glu_serum"] = df["max_glu_serum"].map({"None":1,">300":2, "Norm":3, ">200":4}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
df["payer_code"].unique()
# Out:
# array(['MC', 'SP', '?', 'BC', 'CP', 'UN', 'CM', 'MD', 'HM', 'OG', 'WC',
#        'DM', 'PO', 'OT', 'SI', 'CH', 'MP', 'FR'], dtype=object)

# %%
df["payer_code"] = df["payer_code"].map({'MC':1, 'SP':2, '?':-1, 'BC':3, 'CP':4, 'UN':5, 'CM':6, 'MD':7, 'HM':8, 'OG':9, 'WC':10,
       'DM':11, 'PO':12, 'OT':13, 'SI':14, 'CH':15, 'MP':16, 'FR':17}.get)
df
# Out:
#               id  patient_no  cast  gender  age group weight  \
# 0      122283168   113223627     1       0          1      ?
# 1       97835454    25776306     1       0          1      ?
# 2      431347352    42491844     1       1          2      ?
# 3      153301914    87104907     1       0          3      ?
# 4      304851608    70844364     1       0          4      ?
# ...          ...         ...   ...     ...        ...    ...
# 71231   64367586    89250084     1       0          1      ?
# 71232  290180694    44177697     1       1          5      ?
# 71233  130101072   113734728     1       0          1      ?
# 71234   26933646   107965575     1       0          1      ?
# 71235  189027114    71449254     1       0          2      ?
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# 0                     1                         1                    7
# 1                     5                         3                   17
# ...

# %%
print(df.describe())
# Out:
#                  id    patient_no          cast        gender     age group  \
# count  7.123600e+04  7.123600e+04  71236.000000  71236.000000  71236.000000
# mean   1.654762e+08  5.438454e+07      1.361152      0.463614      3.623505
# std    1.026980e+08  3.871642e+07      0.761313      0.498734      2.064240
# min    1.573800e+04  1.350000e+02      1.000000      0.000000      1.000000
# 25%    8.517515e+07  2.342767e+07      1.000000      0.000000      2.000000
# 50%    1.526683e+08  4.547114e+07      1.000000      0.000000      3.000000
# 75%    2.307590e+08  8.747864e+07      2.000000      1.000000      5.000000
# max    4.438672e+08  1.895026e+08      5.000000      2.000000     10.000000
#
#        admission_typeid  discharge_disposition_id  admission_source_id  \
# count      71236.000000              71236.000000         71236.000000
# mean           2.022447                  3.714751             5.742195
# ...

# %%
df=df.drop(columns=['id', 'cast','patient_no','diag_1','diag_2','diag_3','medical_specialty', 'weight'])
print(df.describe())
# Out:
#              gender     age group  admission_typeid  discharge_disposition_id  \
# count  71236.000000  71236.000000      71236.000000              71236.000000
# mean       0.463614      3.623505          2.022447                  3.714751
# std        0.498734      2.064240          1.442203                  5.277423
# min        0.000000      1.000000          1.000000                  1.000000
# 25%        0.000000      2.000000          1.000000                  1.000000
# 50%        0.000000      3.000000          1.000000                  1.000000
# 75%        1.000000      5.000000          3.000000                  4.000000
# max        2.000000     10.000000          8.000000                 28.000000
#
#        admission_source_id  time_in_hospital    payer_code  \
# count         71236.000000      71236.000000  71236.000000
# mean              5.742195          4.394534      1.515905
# std               4.067795          2.988832      3.092952
# ...

# %%
df1 = pd.read_csv('Y_train.csv')
df1
# Out:
#       label
# 0        NO
# 1        NO
# 2       <30
# 3        NO
# 4        NO
# ...     ...
# 71231   <30
# 71232    NO
# 71233    NO
# 71234    NO
# 71235    >5
#
# [71236 rows x 1 columns]

# %%
df1['label'].unique()
# Out:
# array(['NO', '<30', '>5'], dtype=object)

# %%
df1["label"] = df1["label"].map({"NO":0,"<30":1, ">5":2}.get)
print(df1)
# Out:
#        label
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 71231      1
# 71232      0
# 71233      0
# 71234      0
# 71235      2
#
# [71236 rows x 1 columns]

# %%
x = df.to_numpy()
print(x.shape)
# Out:
# (71236, 41)

# %%
from sklearn.preprocessing import LabelEncoder
y = df1.apply(LabelEncoder().fit_transform)

# %%
# y.head(48)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
log_model.fit(x,y)
# Out:
# C:\Users\Nadeem Khan\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Nadeem Khan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
log_model.score(x,y)
# Out:
# 0.5701471166264248
